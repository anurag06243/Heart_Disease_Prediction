# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\hp\Downloads\Heart_Disease_Prediction.ipynb Cell 1 line 3
#       <a href='vscode-notebook-cell:/c%3A/Users/hp/Downloads/Heart_Disease_Prediction.ipynb#W0sZmlsZQ%3D%3D?line=0'>1</a> import numpy as np
#       <a href='vscode-notebook-cell:/c%3A/Users/hp/Downloads/Heart_Disease_Prediction.ipynb#W0sZmlsZQ%3D%3D?line=1'>2</a> import pandas as pd
# ----> <a href='vscode-notebook-cell:/c%3A/Users/hp/Downloads/Heart_Disease_Prediction.ipynb#W0sZmlsZQ%3D%3D?line=2'>3</a> from sklearn.model_selection import train_test_split
#       <a href='vscode-notebook-cell:/c%3A/Users/hp/Downloads/Heart_Disease_Prediction.ipynb#W0sZmlsZQ%3D%3D?line=3'>4</a> from sklearn.linear_model import LogisticRegression
# ...

# %%
heart_data=pd.read_csv('/content/heart.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Users\hp\Downloads\Heart_Disease_Prediction.ipynb Cell 2 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/hp/Downloads/Heart_Disease_Prediction.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> heart_data=pd.read_csv('/content/heart.csv')
#
# ...

# %%
heart_data
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %%
heart_data = pd.read_csv(r'C:\Users\hp\Desktop\ml project placement\heart disease dataset')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-457c220180db> in <cell line: 1>()
# ----> 1 heart_data = pd.read_csv(r'C:\Users\hp\Desktop\ml project placement\heart disease dataset')
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
heart_data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
heart_data.tail()
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 1020      2   0     2       1
# 1021      1   1     3       0
# 1022      1   1     2       0
# 1023      2   0     2       1
# 1024      1   1     3       0

# %%
heart_data.shape
# Out:
# (1025, 14)

# %%
heart_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %%
heart_data.describe()
#% given is percentile
# Out:
#                age          sex           cp     trestbps        chol  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.00000
# mean     54.434146     0.695610     0.942439   131.611707   246.00000
# std       9.072290     0.460373     1.029641    17.516718    51.59251
# min      29.000000     0.000000     0.000000    94.000000   126.00000
# 25%      48.000000     0.000000     0.000000   120.000000   211.00000
# 50%      56.000000     1.000000     1.000000   130.000000   240.00000
# 75%      61.000000     1.000000     2.000000   140.000000   275.00000
# max      77.000000     1.000000     3.000000   200.000000   564.00000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean      0.149268     0.529756   149.114146     0.336585     1.071512
# std       0.356527     0.527878    23.005724     0.472772     1.175053
# ...

# %%
heart_data["target"].value_counts()
# Out:
# 1    526
# 0    499
# Name: target, dtype: int64

# %%
x=heart_data.drop(columns='target',axis=1)

# %%
x
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal
# 0         2   2     3
# 1         0   0     3
# ...

# %%
y=heart_data["target"]

# %%
y
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1020    1
# 1021    0
# 1022    0
# 1023    1
# 1024    0
# Name: target, Length: 1025, dtype: int64

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.4,stratify=y,random_state=2)

# %%
x_train
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 936   43    1   2       130   315    0        1      162      0      1.9
# 541   44    1   2       140   235    0        0      180      0      0.0
# 774   48    0   2       130   275    0        1      139      0      0.2
# 750   55    1   1       130   262    0        1      155      0      0.0
# 434   41    0   2       112   268    0        0      172      1      0.0
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 61    66    0   2       146   278    0        0      152      0      0.0
# 221   63    1   0       130   254    0        0      147      0      1.4
# 365   53    1   2       130   246    1        0      173      0      0.0
# 281   35    1   1       122   192    0        1      174      0      0.0
# 966   58    1   0       128   259    0        0      130      1      3.0
#
#      slope  ca  thal
# 936      2   1     2
# 541      2   0     2
# 774      2   0     2
# ...

# %%
x_test
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 760   57    1   0       150   276    0        0      112      1      0.6
# 751   65    0   2       160   360    0        0      151      0      0.8
# 667   57    1   1       124   261    0        1      141      0      0.3
# 118   29    1   1       130   204    0        0      202      0      0.0
# 293   59    1   2       150   212    1        1      157      0      1.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 283   64    1   3       110   211    0        0      144      1      1.8
# 884   70    1   0       145   174    0        1      125      1      2.6
# 278   55    1   0       160   289    0        0      145      1      0.8
# 765   57    1   0       110   335    0        1      143      1      3.0
# 523   61    1   0       148   203    0        1      161      0      0.0
#
#      slope  ca  thal
# 760      1   1     1
# 751      2   0     2
# 667      2   0     3
# ...

# %%
y_test , y_train
# Out:
# (760    0
#  751    1
#  667    0
#  118    1
#  293    1
#        ..
#  283    1
#  884    0
#  278    0
#  765    0
#  523    0
#  Name: target, Length: 410, dtype: int64,
#  936    1
#  541    1
#  774    1
#  750    1
#  434    1
#        ..
#  61     1
#  221    0
#  365    1
#  281    1
#  966    0
#  Name: target, Length: 615, dtype: int64)

# %%
model=LogisticRegression()

# %%
model.fit(x_train, y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
x_train_predict=model.predict(x_train)
x_train_accuracy=accuracy_score(x_train_predict,y_train)

# %%
round(x_train_accuracy*100,2)
# Out:
# 86.18

# %%
x_test_predict=model.predict(x_test)
x_test_accuracy=accuracy_score(x_test_predict,y_test)

# %%
round(x_test_accuracy*100,2)
# Out:
# 81.71

# %%
input_data=(52,1,0,125,212,	0,	1,	168,	0,	1.0,	2,	2,	3)
input_data_asarray=np.asarray(input_data)
input_data_reshaped=input_data_asarray.reshape(1,-1)
input_data_prediction=model.predict(input_data_reshaped)
input_data_prediction[0]

if(input_data_prediction[0]==0):
  print("No heart diesease")
else:
  print("person is suffering from heart disease")
# Out:
# No heart diesease
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
input_data=(59,	1,	1,	140,	221,	0,	1,	164,	1,	0.0,	2,	0,	2	)
input_data_asarray=np.asarray(input_data)
input_data_reshaped=input_data_asarray.reshape(1,-1)
input_data_prediction=model.predict(input_data_reshaped)
input_data_prediction[0]

if(input_data_prediction[0]==0):
  print("No heart diesease")
else:
  print("person is suffering from heart disease")
# Out:
# person is suffering from heart disease
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
